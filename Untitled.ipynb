# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv(r'C:\Users\User\Documents\GitHub\HorseData\horse.csv')
df = df.drop(columns = 'hospital_number')

# %%
df
# Out:
#     surgery    age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 0        no  adult         38.5   66.0              28.0                cool
# 1       yes  adult         39.2   88.0              20.0                 NaN
# 2        no  adult         38.3   40.0              24.0              normal
# 3       yes  young         39.1  164.0              84.0                cold
# 4        no  adult         37.3  104.0              35.0                 NaN
# ..      ...    ...          ...    ...               ...                 ...
# 294     yes  adult          NaN  120.0              70.0                cold
# 295      no  adult         37.2   72.0              24.0                cool
# 296     yes  adult         37.5   72.0              30.0                cold
# 297     yes  adult         36.5  100.0              24.0                cool
# 298     yes  adult         37.2   40.0              20.0                 NaN
#
# ...

# %%
v0 = [x for x in df['pain'].isnull() if x == False]
# len(v)
v_null = [x for x in df['pain'].isnull() if x == True]
print(len(v0),',', len(v_null), ',The number of null variables is :', len(v_null))
# Out:
# 244 , 55 ,The number of null variables is : 55

# %%
# Out:
# <bound method DataFrame.info of     surgery    age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 0        no  adult         38.5   66.0              28.0                cool
# 1       yes  adult         39.2   88.0              20.0                 NaN
# 2        no  adult         38.3   40.0              24.0              normal
# 3       yes  young         39.1  164.0              84.0                cold
# 4        no  adult         37.3  104.0              35.0                 NaN
# ..      ...    ...          ...    ...               ...                 ...
# 294     yes  adult          NaN  120.0              70.0                cold
# 295      no  adult         37.2   72.0              24.0                cool
# 296     yes  adult         37.5   72.0              30.0                cold
# 297     yes  adult         36.5  100.0              24.0                cool
# 298     yes  adult         37.2   40.0              20.0                 NaN
#
# ...

# %%
b = "this is a new string"
